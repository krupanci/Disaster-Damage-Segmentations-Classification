# %%
# !pip install imantics
# !pip install patchify

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = "/content/drive/MyDrive/parts_train_data_inter/test_images_labels_targets.tar"
for root, dirs, files in os.walk(path):
    for file in files:
        print(os.path.join(root, file))

# %%
# !tar -xf /content/drive/MyDrive/parts_train_data_inter/test_images_labels_targets.tar -C /content/

# %%
import os

extracted_path = '/content/'
for root, dirs, files in os.walk(extracted_path):
    for name in files[:10]:
        print(os.path.join(root, name))
    break

import os

labels_path = '/content/test/images'

for name in os.listdir(labels_path)[:10]:
    print(name)
# Out:
# mexico-earthquake_00000113_pre_disaster.png
# hurricane-florence_00000087_post_disaster.png
# hurricane-michael_00000089_pre_disaster.png
# socal-fire_00000325_pre_disaster.png
# midwest-flooding_00000354_pre_disaster.png
# socal-fire_00000885_post_disaster.png
# socal-fire_00001138_pre_disaster.png
# palu-tsunami_00000163_pre_disaster.png
# hurricane-florence_00000077_post_disaster.png
# midwest-flooding_00000332_post_disaster.png

# %%
import os
import glob

image_dir = '/content/test/images'
target_dir = '/content/test/targets'
label_dir = '/content/test/labels'

train_dict = {}

# Loop through target masks
for target_path in glob.glob(os.path.join(target_dir, '*_target.png')):
    filename = os.path.basename(target_path)

    # Remove _pre_disaster_target.png or _post_disaster_target.png
    if '_pre_disaster_target.png' in filename:
        base_id = filename.replace('_pre_disaster_target.png', '')
    elif '_post_disaster_target.png' in filename:
        base_id = filename.replace('_post_disaster_target.png', '')
    else:
        continue  # skip invalid names

    pre_img = os.path.join(image_dir, base_id + '_pre_disaster.png')
    post_img = os.path.join(image_dir, base_id + '_post_disaster.png')
    label_json = os.path.join(label_dir, base_id + '_post_disaster.json')

    if os.path.exists(pre_img) and os.path.exists(post_img):
        train_dict[base_id] = {
            'pre_image': pre_img,
            'post_image': post_img,
            'target_mask': target_path,
            'label_json': label_json if os.path.exists(label_json) else None
        }
    else:
        print(f"Missing: {base_id}")
        if not os.path.exists(pre_img):
            print(" - Missing pre:", pre_img)
        if not os.path.exists(post_img):
            print(" - Missing post:", post_img)

# Preview one example
from pprint import pprint
pprint(dict(list(train_dict.items())[:1]))
# Out:
# {'socal-fire_00000000': {'label_json': '/content/test/labels/socal-fire_00000000_post_disaster.json',
#                          'post_image': '/content/test/images/socal-fire_00000000_post_disaster.png',
#                          'pre_image': '/content/test/images/socal-fire_00000000_pre_disaster.png',
#                          'target_mask': '/content/test/targets/socal-fire_00000000_pre_disaster_target.png'}}

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf



@tf.keras.utils.register_keras_serializable(package="Custom")
def bulinding_iou(y_true, y_pred):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    # Only keep patches that have some damage
    mask = tf.reduce_sum(y_true, axis=[1,2,3]) > 0
    y_true = tf.boolean_mask(y_true, mask)
    y_pred = tf.boolean_mask(y_pred, mask)

    # If no damage patches exist, return 0
    def compute_iou():
        intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
        union = tf.reduce_sum(y_true, axis=[1,2,3]) + tf.reduce_sum(y_pred, axis=[1,2,3]) - intersection
        return tf.reduce_mean(intersection / (union + 1e-7))

    return tf.cond(tf.size(y_true) > 0, compute_iou, lambda: 0.0)

@tf.keras.utils.register_keras_serializable(package="Custom")
def bulinding_f1_per_class(y_true, y_pred):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    # Only damage class
    intersection = tf.reduce_sum(y_true * y_pred)
    precision = intersection / (tf.reduce_sum(y_pred) + 1e-7)
    recall = intersection / (tf.reduce_sum(y_true) + 1e-7)
    return 2 * precision * recall / (precision + recall + 1e-7)
model = load_model(
    "/content/drive/MyDrive/bulinding_seg_resnet34.keras",
    custom_objects={
        "bulinding_iou": bulinding_iou,
        "bulinding_f1_per_class": bulinding_f1_per_class
    },
    compile=False  # safer for custom losses
)

# %%
# import tensorflow as tf

# @tf.keras.utils.register_keras_serializable()
# class SparseCategoricalFocalLoss(tf.keras.losses.Loss):
#     def __init__(self, gamma=2.0, class_weights=None, label_smoothing=0.05,
#                  reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE,
#                  name="sparse_categorical_focal_loss", **kwargs):
#         super().__init__(reduction=reduction, name=name, **kwargs)
#         self.gamma = gamma
#         self.label_smoothing = label_smoothing
#         self.class_weights = tf.constant(class_weights, dtype=tf.float32) if class_weights is not None else None

#     def call(self, y_true, y_pred):
#         """
#         y_true: (batch,) integer class labels
#         y_pred: (batch, num_classes) softmax probabilities
#         """
#         y_true = tf.cast(y_true, tf.int32)
#         y_pred = tf.clip_by_value(y_pred, 1e-8, 1.0 - 1e-8)

#         num_classes = tf.shape(y_pred)[-1]
#         y_true_one_hot = tf.one_hot(y_true, depth=num_classes, dtype=tf.float32)

#         # --- Apply label smoothing ---
#         if self.label_smoothing > 0:
#             smooth_positives = 1.0 - self.label_smoothing
#             smooth_negatives = self.label_smoothing / tf.cast(num_classes - 1, tf.float32)
#             y_true_one_hot = y_true_one_hot * smooth_positives + smooth_negatives

#         # --- Compute focal loss ---
#         pt = tf.reduce_sum(y_true_one_hot * y_pred, axis=-1)
#         focal_factor = tf.pow(1.0 - pt, self.gamma)
#         ce_loss = -tf.reduce_sum(y_true_one_hot * tf.math.log(y_pred), axis=-1)
#         loss = focal_factor * ce_loss

#         # --- Apply class weights (optional) ---
#         if self.class_weights is not None:
#             weights = tf.gather(self.class_weights, y_true)
#             loss = loss * weights

#         return tf.reduce_mean(loss)

#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "gamma": self.gamma,
#             "label_smoothing": self.label_smoothing,
#             "class_weights": self.class_weights.numpy().tolist() if self.class_weights is not None else None,
#         })
#         return config
# #class_weights = [0.28, 4.27, 2.20, 1.67]
# #class_weights = [0.05, 0.8, 0.6, 0.3]
# #class_weights = [0.1, 0.4, 0.3, 0.2]
# class_weights= [0.05041411, 0.43280042, 0.29408234, 0.22270313]


import tensorflow as tf

@tf.keras.utils.register_keras_serializable()
class HybridWeightedFocalLoss(tf.keras.losses.Loss):
    def __init__(self,
                 class_weights=None,
                 label_smoothing=0.0,
                 gamma=2.0,
                 lam=0.5,
                 reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE,
                 name="hybrid_weighted_focal_loss",
                 **kwargs):
        """
        lam in [0,1] mixes between WCCE and Focal:
          loss = (1-lam) * WCCE + lam * FocalWeighted
        gamma is focal gamma.
        class_weights: list/array-like of len=num_classes or None.
        """
        super().__init__(reduction=reduction, name=name, **kwargs)
        self.class_weights = tf.constant(class_weights, dtype=tf.float32) if class_weights is not None else None
        self.label_smoothing = float(label_smoothing)
        self.gamma = float(gamma)
        self.lam = float(lam)

    def call(self, y_true, y_pred):
        # y_true: (batch,) integer labels
        # y_pred: (batch, num_classes) softmax probabilities
        y_true = tf.cast(y_true, tf.int32)
        y_pred = tf.clip_by_value(y_pred, 1e-8, 1.0 - 1e-8)
        num_classes = tf.shape(y_pred)[-1]
        y_true_one_hot = tf.one_hot(y_true, depth=num_classes, dtype=tf.float32)

        # label smoothing
        if self.label_smoothing > 0:
            smooth_pos = 1.0 - self.label_smoothing
            smooth_neg = self.label_smoothing / tf.cast(num_classes - 1, tf.float32)
            y_true_one_hot = y_true_one_hot * smooth_pos + smooth_neg

        # standard cross-entropy per sample
        ce_per_sample = -tf.reduce_sum(y_true_one_hot * tf.math.log(y_pred), axis=-1)

        # class weights per sample (gather by int label)
        if self.class_weights is not None:
            sample_weights = tf.gather(self.class_weights, y_true)
        else:
            sample_weights = 1.0

        # Weighted Categorical Cross-Entropy (scalar per sample)
        wce = ce_per_sample * sample_weights

        # Focal part: focal factor computed w.r.t. true class probability pt
        pt = tf.reduce_sum(y_true_one_hot * y_pred, axis=-1)  # p_t
        focal_factor = tf.pow(1.0 - pt, self.gamma)
        focal_loss = focal_factor * ce_per_sample

        # apply same class weights to focal part (keeps balance)
        focal_loss = focal_loss * sample_weights

        # Mix them
        loss = (1.0 - self.lam) * wce + self.lam * focal_loss

        return tf.reduce_mean(loss)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "class_weights": self.class_weights.numpy().tolist() if self.class_weights is not None else None,
            "label_smoothing": self.label_smoothing,
            "gamma": self.gamma,
            "lam": self.lam,
        })
        return cfg




import tensorflow as tf
import numpy as np

# ---------------- Multi-class Precision ---------------- #
@tf.keras.utils.register_keras_serializable()
class MultiClassPrecision(tf.keras.metrics.Metric):
    def __init__(self, num_classes=4, name="precision", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.tp = self.add_weight(shape=(num_classes,), initializer="zeros", dtype=tf.float32)
        self.fp = self.add_weight(shape=(num_classes,), initializer="zeros", dtype=tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)

        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=self.num_classes, dtype=tf.float32)
        tp = tf.linalg.diag_part(cm)
        fp = tf.reduce_sum(cm, axis=0) - tp

        self.tp.assign_add(tp)
        self.fp.assign_add(fp)

    def result(self):
        precision = self.tp / (self.tp + self.fp + 1e-8)
        return precision  # <-- return per-class precision

    def reset_state(self):
        for v in self.variables:
            v.assign(tf.zeros_like(v))


# ---------------- Multi-class Recall ---------------- #
@tf.keras.utils.register_keras_serializable()
class MultiClassRecall(tf.keras.metrics.Metric):
    def __init__(self, num_classes=4, name="recall", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.tp = self.add_weight(shape=(num_classes,), initializer="zeros", dtype=tf.float32)
        self.fn = self.add_weight(shape=(num_classes,), initializer="zeros", dtype=tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)

        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=self.num_classes, dtype=tf.float32)
        tp = tf.linalg.diag_part(cm)
        fn = tf.reduce_sum(cm, axis=1) - tp

        self.tp.assign_add(tp)
        self.fn.assign_add(fn)

    def result(self):
        recall = self.tp / (self.tp + self.fn + 1e-8)
        return recall  # <-- return per-class recall

    def reset_state(self):
        for v in self.variables:
            v.assign(tf.zeros_like(v))


# ---------------- Per-Class Harmonic Mean ---------------- #
import tensorflow as tf

@tf.keras.utils.register_keras_serializable()
class PerClassHarmonicMean(tf.keras.metrics.Metric):
    def __init__(self, num_classes=4, name="harmonic_mean", **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.eps = 1e-8

        # Store confusion components
        self.tp = self.add_weight(shape=(num_classes,), initializer="zeros", dtype=tf.float32)
        self.fp = self.add_weight(shape=(num_classes,), initializer="zeros", dtype=tf.float32)
        self.fn = self.add_weight(shape=(num_classes,), initializer="zeros", dtype=tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Flatten
        y_true = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int32)
        y_pred = tf.reshape(y_pred, [-1])

        # Compute confusion matrix
        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=self.num_classes, dtype=tf.float32)
        tp = tf.linalg.diag_part(cm)
        fp = tf.reduce_sum(cm, axis=0) - tp
        fn = tf.reduce_sum(cm, axis=1) - tp

        # Accumulate totals
        self.tp.assign_add(tp)
        self.fp.assign_add(fp)
        self.fn.assign_add(fn)

    def result(self):
        precision = self.tp / (self.tp + self.fp + self.eps)
        recall = self.tp / (self.tp + self.fn + self.eps)
        harmonic = 2.0 / ((1.0 / (precision + self.eps)) + (1.0 / (recall + self.eps)))

        # Return macro-average harmonic mean (mean of all classes)
        return tf.reduce_mean(harmonic)

    def reset_state(self):
        for v in self.variables:
            v.assign(tf.zeros_like(v))



import matplotlib.pyplot as plt

# ---------------- Per-Class Metrics Callback ---------------- #
@tf.keras.utils.register_keras_serializable()
class PerClassMetrics(tf.keras.callbacks.Callback):
    def __init__(self, x_val, y_val, num_classes=4, store_history=True):
        super().__init__()
        self.x_val = x_val
        self.y_val = y_val
        self.num_classes = num_classes
        self.store_history = store_history
        self.history = []  # store per-class metrics over epochs
        self.last_recall = None  # store last per-class recall for external logic

    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.x_val, verbose=0)
        y_pred = np.argmax(y_pred, axis=1)
        y_true = np.array(self.y_val).reshape(-1)

        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=self.num_classes).numpy()
        tp = np.diag(cm)
        fp = np.sum(cm, axis=0) - tp
        fn = np.sum(cm, axis=1) - tp

        precision = tp / (tp + fp + 1e-8)
        recall = tp / (tp + fn + 1e-8)
        harmonic = 2.0 / ((1.0 / (precision + 1e-8)) + (1.0 / (recall + 1e-8)))

        print(f"\nEpoch {epoch+1} — Per-class metrics:")
        for i in range(self.num_classes):
            print(f"  Class {i}: Precision = {precision[i]:.3f}, Recall = {recall[i]:.3f}, Harmonic = {harmonic[i]:.3f}")
        print("-" * 60)

        # store results
        if self.store_history:
            self.history.append({
                'epoch': epoch + 1,
                'precision': precision.tolist(),
                'recall': recall.tolist(),
                'harmonic': harmonic.tolist()
            })
        self.last_recall = recall

    def get_config(self):
        return {
            "num_classes": self.num_classes,
            "store_history": self.store_history
        }

from tensorflow.keras.applications.resnet50 import preprocess_input

custom_objects = {
    "MultiClassPrecision": MultiClassPrecision,
    "MultiClassRecall": MultiClassRecall,
    "PerClassHarmonicMean": PerClassHarmonicMean,
    "preprocess_input": preprocess_input  # <-- add the lambda function here
}

dc_model = tf.keras.models.load_model("/content/drive/MyDrive/updated_efficientNETB0_1111.keras", custom_objects=custom_objects)

# %%
import os
import cv2
import numpy as np
from PIL import Image
from imantics import Mask
from tensorflow.keras.applications.efficientnet import preprocess_input

# ----------------- Config -----------------
PATCH_SIZE = 256
STEP_SIZE = 128      # 50% overlap
BATCH_SIZE = 8
CROP_SIZE = 224
PAD_RATIO = 0.15

# ----------------- Utilities -----------------
def load_image_rgb(path):
    """Load image as RGB array"""
    return np.array(Image.open(path).convert("RGB"))

def pad_to_multiple(image, patch_size=PATCH_SIZE, step=STEP_SIZE):
    """Pad image so its dimensions are compatible with patch and step"""
    h, w = image.shape[:2]
    new_h = ((h - patch_size) // step + 1) * step + patch_size
    new_w = ((w - patch_size) // step + 1) * step + patch_size
    pad_h, pad_w = new_h - h, new_w - w
    pad_width = ((0, pad_h), (0, pad_w), (0, 0))
    return np.pad(image, pad_width, mode='constant', constant_values=0), h, w

def gaussian_kernel(size=PATCH_SIZE, sigma=40):
    """Generate 2D Gaussian kernel for soft blending"""
    ax = np.linspace(-(size - 1) / 2., (size - 1) / 2., size)
    xx, yy = np.meshgrid(ax, ax)
    kernel = np.exp(-0.5 * (np.square(xx) + np.square(yy)) / np.square(sigma))
    return kernel / np.max(kernel)

def sharpen_image(image):
    gaussian = cv2.GaussianBlur(image, (3, 3), 1.0)
    return cv2.addWeighted(image, 1.5, gaussian, -0.5, 0)

def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    cl = clahe.apply(l)
    merged = cv2.merge((cl, a, b))
    return cv2.cvtColor(merged, cv2.COLOR_LAB2BGR)

# ----------------- Segmentation Inference -----------------
def infer_segmentation_mask(seg_model, image, patch_size=PATCH_SIZE, step=STEP_SIZE):
    """Inference with overlapping patches and Gaussian blending"""
    h, w, c = image.shape
    padded_img, orig_h, orig_w = pad_to_multiple(image, patch_size, step)
    H, W = padded_img.shape[:2]

    pred_accum = np.zeros((H, W), dtype=np.float32)
    weight_accum = np.zeros((H, W), dtype=np.float32)
    g_kernel = gaussian_kernel(size=patch_size, sigma=40)

    for y in range(0, H - patch_size + 1, step):
        for x in range(0, W - patch_size + 1, step):
            patch = padded_img[y:y+patch_size, x:x+patch_size]
            patch_input = np.expand_dims(patch.astype('float32') / 255.0, axis=0)
            pred = seg_model.predict(patch_input, verbose=0)[0]

            if pred.ndim == 3 and pred.shape[-1] == 1:
                pred = np.squeeze(pred, axis=-1)

            pred_accum[y:y+patch_size, x:x+patch_size] += pred * g_kernel
            weight_accum[y:y+patch_size, x:x+patch_size] += g_kernel

    seg_full = pred_accum / np.maximum(weight_accum, 1e-7)
    seg_full = seg_full[:orig_h, :orig_w]
    building_mask = (seg_full > 0.8).astype(np.uint8)
    return building_mask

# ----------------- Crop Polygon With Context -----------------
def crop_polygon_with_context(img_pre, img_post, poly, pad_ratio=PAD_RATIO):
    coords = np.array(poly, dtype=np.int32)
    if coords.ndim == 1:
        coords = coords.reshape(-1, 2)
    if len(coords) < 3:
        return None

    x, y, w, h = cv2.boundingRect(coords)
    pad = int(pad_ratio * max(w, h))
    x1, y1 = max(0, x - pad), max(0, y - pad)
    x2, y2 = min(img_pre.shape[1], x + w + pad), min(img_pre.shape[0], y + h + pad)
    cropped_pre = img_pre[y1:y2, x1:x2]
    cropped_post = img_post[y1:y2, x1:x2]
    return cropped_pre, cropped_post, (x1, y1, x2, y2)

# ----------------- Main Pipeline -----------------
def extract_buildings_and_predict_damage(info, seg_model, dmg_model):
    """Predict building polygons and classify their damage."""
    img_pre = load_image_rgb(info['pre_image'])
    img_post = load_image_rgb(info['post_image'])

    # --- Load ground truth mask ---
    mask_gt = None
    mask_path = info.get('target_mask') or info.get('mask_image')
    if mask_path and os.path.exists(mask_path):
        mask_gt = np.array(Image.open(mask_path).convert('L'))

    # --- Segmentation prediction ---
    building_mask = infer_segmentation_mask(seg_model, img_pre)
    polygons = Mask(building_mask).polygons().points

    predictions = []

    for idx, poly in enumerate(polygons):
        crops = crop_polygon_with_context(img_pre, img_post, poly)
        if crops is None:
            continue
        cropped_pre, cropped_post, (x1, y1, x2, y2) = crops

        # --- Enhancement first ---
        cropped_pre = apply_clahe(sharpen_image(cropped_pre))
        cropped_post = apply_clahe(sharpen_image(cropped_post))

        # --- Resize after enhancement ---
        cropped_pre = cv2.resize(cropped_pre, (CROP_SIZE, CROP_SIZE))
        cropped_post = cv2.resize(cropped_post, (CROP_SIZE, CROP_SIZE))

        # --- Preprocess for EfficientNet ---
        img_pre_p = preprocess_input(np.expand_dims(cropped_pre.astype(np.float32), axis=0))
        img_post_p = preprocess_input(np.expand_dims(cropped_post.astype(np.float32), axis=0))

        # --- Damage prediction (0–3) ---
        pred = dmg_model.predict([img_pre_p, img_post_p], verbose=0)
        damage_level_pred = np.argmax(pred, axis=1)[0]   # 0–3, same as training
        confidence = np.max(pred)

        # --- True label from mask (shifted 0–3) ---
        true_label_shifted = None
        if isinstance(mask_gt, np.ndarray) and mask_gt.ndim == 2:
            mask_crop = mask_gt[y1:y2, x1:x2]
            unique_vals = np.unique(mask_crop)
            unique_vals = unique_vals[unique_vals > 0]  # ignore background
            if len(unique_vals) > 0:
                true_label_shifted = int(np.median(unique_vals)) - 1  # shift 1–4 → 0–3

        predictions.append({
            "building_id": idx,
            "polygon": poly.tolist(),
            "damage_level_pred": int(damage_level_pred),
            "damage_level_true": true_label_shifted,
            "confidence": float(confidence)
        })

    return predictions

# ------------------ Predict Damage for Test ------------------ #
def predict_damage_classes_for_test(train_dict, seg_model, dmg_model, num_samples=10):
    """Run inference and print Predicted vs True damage."""
    import random
    keys = random.sample(list(train_dict.keys()), min(num_samples, len(train_dict)))
    results = []

    for key in keys:
        info = train_dict[key]
        preds = extract_buildings_and_predict_damage(info, seg_model, dmg_model)

        if len(preds) == 0:
            print(f"{key}: No buildings detected")
            results.append((-1, -1))
            continue

        best_pred = max(preds, key=lambda x: x['confidence'])
        pred_class = best_pred['damage_level_pred']  # 0–3
        true_class = best_pred.get('damage_level_true', 'N/A')  # 0–3

        # --- For display only (optional) ---
        display_pred = pred_class + 1 if pred_class >= 0 else 'N/A'
        display_true = true_class + 1 if true_class is not None else 'N/A'

        print(f"{key}: Predicted Damage → {display_pred}, True Damage → {display_true}")
        results.append((pred_class, true_class))  # store 0–3 for metric evaluation

    return results

# %% [markdown]
# # visualization

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from PIL import Image
import random

# --- Color mapping for damage levels (0–3) --- #
DAMAGE_COLORS = {
    0: (0, 255, 0),      # Green – No damage
    1: (255, 255, 0),    # Yellow – Minor
    2: (255, 165, 0),    # Orange – Major
    3: (255, 0, 0)       # Red – Destroyed
}

def load_image_rgb(path):
    """Load image as RGB array"""
    return np.array(Image.open(path).convert("RGB"))

def visualize_predictions_with_gt(info, seg_model, dmg_model):
    """Visualize pre, post, predicted seg mask, GT seg mask, predicted damage, and GT damage."""
    img_pre = load_image_rgb(info['pre_image'])
    img_post = load_image_rgb(info['post_image'])

    # --- Run segmentation prediction separately (binary mask) ---
    pred_seg_mask = infer_segmentation_mask(seg_model, img_pre)

    # --- Ground truth building mask (if exists) ---
    gt_seg_mask = None
    mask_path = info.get('building_mask') or info.get('target_mask') or info.get('mask_image')
    if mask_path and os.path.exists(mask_path):
        gt_seg_mask = np.array(Image.open(mask_path).convert('L'))
        gt_seg_mask = (gt_seg_mask > 0).astype(np.uint8)

    # --- Run damage classification prediction ---
    preds = extract_buildings_and_predict_damage(info, seg_model, dmg_model)
    if len(preds) == 0:
        print("No buildings detected.")
        return

    # ---------------- Predicted damage overlay ---------------- #
    overlay_pred = img_post.copy()
    for p in preds:
        poly = np.array(p["polygon"], dtype=np.int32)
        dmg = p["damage_level_pred"]  # 0–3
        color = DAMAGE_COLORS.get(dmg, (255, 255, 255))

        overlay_fill = overlay_pred.copy()
        cv2.fillPoly(overlay_fill, [poly], color)
        overlay_pred = cv2.addWeighted(overlay_pred, 0.7, overlay_fill, 0.3, 0)
        cv2.polylines(overlay_pred, [poly], isClosed=True, color=(0, 0, 0), thickness=1)

    # ---------------- Ground truth damage overlay ---------------- #
    gt_overlay = img_post.copy()
    gt_mask_color = None
    mask_path = info.get('target_mask') or info.get('mask_image')

    if mask_path and os.path.exists(mask_path):
        mask_gt = np.array(Image.open(mask_path))
        if mask_gt.ndim == 3:
            gt_mask_color = mask_gt
            mask_gt = cv2.cvtColor(mask_gt, cv2.COLOR_RGB2GRAY)
            mask_gt_shifted = mask_gt - 1  # 1–4 → 0–3
        else:
            mask_gt_shifted = mask_gt - 1
            gt_mask_color = np.zeros((*mask_gt.shape, 3), dtype=np.uint8)
            for dmg, color in DAMAGE_COLORS.items():
                gt_mask_color[mask_gt_shifted == dmg] = color

        # Overlay version
        for dmg, color in DAMAGE_COLORS.items():
            mask_binary = (mask_gt_shifted == dmg).astype(np.uint8)
            gt_overlay[mask_binary == 1] = (
                0.6 * gt_overlay[mask_binary == 1] + 0.4 * np.array(color)
            ).astype(np.uint8)

    # ---------------- Plotting (6 horizontally) ---------------- #
    fig, axes = plt.subplots(1, 6, figsize=(35, 7))

    axes[0].imshow(img_pre)
    axes[0].set_title("Pre-Disaster Image")

    axes[1].imshow(img_post)
    axes[1].set_title("Post-Disaster Image")

    axes[2].imshow(pred_seg_mask, cmap='gray')
    axes[2].set_title("Predicted Building Mask")

    if gt_seg_mask is not None:
        axes[3].imshow(gt_seg_mask, cmap='gray')
        axes[3].set_title("Ground Truth Building Mask")
    else:
        axes[3].imshow(np.zeros_like(pred_seg_mask), cmap='gray')
        axes[3].set_title("No GT Building Mask")

    axes[4].imshow(overlay_pred)
    axes[4].set_title("Predicted Damage Overlay")

    axes[5].imshow(gt_overlay)
    axes[5].set_title("Ground Truth Damage Overlay")

    for ax in axes:
        ax.axis('off')

    # Legend for damage levels
    legend_patches = [
        mpatches.Patch(color=np.array(c) / 255, label=f"Damage {i}")
        for i, c in DAMAGE_COLORS.items()
    ]
    plt.legend(
        handles=legend_patches,
        loc='lower center',
        bbox_to_anchor=(1.1, -0.1),
        ncol=4,
        frameon=False
    )

    plt.tight_layout()
    plt.show()


def visualize_random_samples(train_dict, seg_model, dmg_model, num_samples=5):
    keys = list(train_dict.keys())
    random_keys = random.sample(keys, min(num_samples, len(keys)))

    for i, key in enumerate(random_keys, 1):
        print(f"\n🔹 Visualizing sample {i}/{len(random_keys)} → {key}")
        info = train_dict[key]

        visualize_predictions_with_gt(info, seg_model, dmg_model)


visualize_random_samples(train_dict, model, dc_model, num_samples=15)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## visualization

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from PIL import Image
import random

# --- Color mapping for damage levels (0–3) --- #
DAMAGE_COLORS = {
    0: (0, 255, 0),      # Green
    1: (255, 255, 0),    # Yellow
    2: (255, 165, 0),    # Orange
    3: (255, 0, 0)       # Red
}

def load_image_rgb(path):
    """Load image as RGB array"""
    return np.array(Image.open(path).convert("RGB"))

def visualize_predictions_with_gt(info, seg_model, dmg_model):
    """Visualize pre, post, predicted overlays, ground truth overlay, and GT mask."""
    img_pre = load_image_rgb(info['pre_image'])
    img_post = load_image_rgb(info['post_image'])

    # Run full prediction pipeline
    preds = extract_buildings_and_predict_damage(info, seg_model, dmg_model)
    if len(preds) == 0:
        print("No buildings detected.")
        return

    # ---------------- Predicted overlay ---------------- #
    overlay_pred = img_post.copy()
    for p in preds:
        poly = np.array(p["polygon"], dtype=np.int32)
        dmg = p["damage_level_pred"]  # 0–3
        color = DAMAGE_COLORS.get(dmg, (255, 255, 255))

        overlay_fill = overlay_pred.copy()
        cv2.fillPoly(overlay_fill, [poly], color)
        overlay_pred = cv2.addWeighted(overlay_pred, 0.7, overlay_fill, 0.3, 0)
        cv2.polylines(overlay_pred, [poly], isClosed=True, color=(0, 0, 0), thickness=1)

    # ---------------- Ground truth overlay + mask ---------------- #
    gt_overlay = img_post.copy()
    gt_mask_color = None
    mask_path = info.get('target_mask') or info.get('mask_image')

    if mask_path and os.path.exists(mask_path):
        mask_gt = np.array(Image.open(mask_path))
        if mask_gt.ndim == 3:  # already RGB
            gt_mask_color = mask_gt
            mask_gt = cv2.cvtColor(mask_gt, cv2.COLOR_RGB2GRAY)
            mask_gt_shifted = mask_gt - 1  # 1–4 → 0–3
        else:
            mask_gt_shifted = mask_gt - 1  # shift 1–4 → 0–3
            gt_mask_color = np.zeros((*mask_gt.shape, 3), dtype=np.uint8)
            for dmg, color in DAMAGE_COLORS.items():
                gt_mask_color[mask_gt_shifted == dmg] = color

        # Overlay ground truth
        for dmg, color in DAMAGE_COLORS.items():
            mask_binary = (mask_gt_shifted == dmg).astype(np.uint8)
            gt_overlay[mask_binary == 1] = (
                0.6 * gt_overlay[mask_binary == 1] + 0.4 * np.array(color)
            ).astype(np.uint8)

    # ---------------- Plotting ---------------- #
    fig, axes = plt.subplots(1, 5, figsize=(25, 6))

    axes[0].imshow(img_pre)
    axes[0].set_title("Pre-Disaster Image")

    axes[1].imshow(img_post)
    axes[1].set_title("Post-Disaster Image")

    axes[2].imshow(overlay_pred)
    axes[2].set_title("Predicted Damage Overlay")

    axes[3].imshow(gt_overlay)
    axes[3].set_title("Ground Truth Overlay")

    if gt_mask_color is not None:
        axes[4].imshow(gt_mask_color)
        axes[4].set_title("Ground Truth Mask (Colored)")
    else:
        axes[4].imshow(np.zeros_like(img_post))
        axes[4].set_title("No Ground Truth Mask")

    for ax in axes:
        ax.axis('off')

    # Legend
    legend_patches = [
        mpatches.Patch(color=np.array(c) / 255, label=f"Damage {i}")
        for i, c in DAMAGE_COLORS.items()
    ]
    plt.legend(
        handles=legend_patches,
        loc='lower center',
        bbox_to_anchor=(1.1, -0.1),
        ncol=4,
        frameon=False
    )

    plt.tight_layout()
    plt.show()


def visualize_random_samples(train_dict, seg_model, dmg_model, num_samples=5):
    keys = list(train_dict.keys())
    random_keys = random.sample(keys, min(num_samples, len(keys)))

    for i, key in enumerate(random_keys, 1):
        print(f"\n🔹 Visualizing sample {i}/{len(random_keys)} → {key}")
        info = train_dict[key]
        visualize_predictions_with_gt(info, seg_model, dmg_model)


# --- Example Run --- #
visualize_random_samples(train_dict, model, dc_model, num_samples=15)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
def debug_label_offset(train_dict, seg_model, dmg_model, num_samples=5):

    import random
    keys = random.sample(list(train_dict.keys()), min(num_samples, len(train_dict)))

    offset_counts = []  # Store GT - Pred for analysis

    for key in keys:
        info = train_dict[key]
        preds = extract_buildings_and_predict_damage(info, seg_model, dmg_model)

        if len(preds) == 0:
            print(f"{key}: No buildings detected")
            continue

        print(f"\nSample: {key}")
        for p in preds:
            pred_class = p["damage_level_pred"]
            true_class = p["damage_level_true"]
            if true_class is None:
                continue
            offset = pred_class - true_class
            offset_counts.append(offset)
            print(f"Building {p['building_id']}: GT={true_class}, Pred={pred_class}, Offset={offset}")

    # Summary of offsets
    if offset_counts:
        import collections
        offset_summary = collections.Counter(offset_counts)
        print("\n--- Offset Summary ---")
        for k, v in offset_summary.items():
            print(f"Offset {k}: {v} instances")
    else:
        print("No valid GT labels found for comparison.")
# Run debug on 5 random samples
debug_label_offset(train_dict, model, dc_model, num_samples=5)
# Out:
# Sample: mexico-earthquake_00000117
# Building 1: GT=0, Pred=0, Offset=0
# Building 2: GT=0, Pred=0, Offset=0
# Building 4: GT=0, Pred=2, Offset=2
# Building 5: GT=0, Pred=0, Offset=0
# Building 7: GT=0, Pred=0, Offset=0
# Building 8: GT=0, Pred=0, Offset=0
# Building 9: GT=0, Pred=0, Offset=0
# Building 10: GT=0, Pred=0, Offset=0
# Building 11: GT=0, Pred=0, Offset=0
# Building 12: GT=0, Pred=2, Offset=2
# Building 14: GT=0, Pred=0, Offset=0
# Building 15: GT=0, Pred=0, Offset=0
# Building 16: GT=0, Pred=0, Offset=0
# Building 17: GT=0, Pred=0, Offset=0
# Building 18: GT=0, Pred=0, Offset=0
# Building 19: GT=0, Pred=0, Offset=0
# Building 20: GT=0, Pred=0, Offset=0
# Building 21: GT=0, Pred=0, Offset=0
# Building 24: GT=0, Pred=3, Offset=3
# Building 25: GT=0, Pred=0, Offset=0
# Building 26: GT=0, Pred=0, Offset=0
# Building 27: GT=0, Pred=3, Offset=3
# Building 28: GT=0, Pred=1, Offset=1
# Building 29: GT=0, Pred=0, Offset=0
# Building 31: GT=0, Pred=0, Offset=0
# Building 32: GT=0, Pred=0, Offset=0
# Building 34: GT=0, Pred=3, Offset=3
# Building 35: GT=0, Pred=2, Offset=2
# Building 36: GT=0, Pred=0, Offset=0
# Building 37: GT=0, Pred=0, Offset=0
# Building 38: GT=0, Pred=0, Offset=0
# Building 39: GT=0, Pred=0, Offset=0
# Building 40: GT=0, Pred=0, Offset=0
# Building 41: GT=0, Pred=0, Offset=0
# Building 42: GT=0, Pred=1, Offset=1
# Building 43: GT=0, Pred=0, Offset=0
# Building 44: GT=0, Pred=0, Offset=0
# Building 45: GT=0, Pred=0, Offset=0
# Building 46: GT=0, Pred=2, Offset=2
# Building 47: GT=0, Pred=0, Offset=0
# Building 48: GT=0, Pred=1, Offset=1
# Building 49: GT=0, Pred=0, Offset=0
# Building 50: GT=0, Pred=2, Offset=2
# Building 51: GT=0, Pred=0, Offset=0
# Building 52: GT=0, Pred=0, Offset=0
# Building 53: GT=0, Pred=0, Offset=0
# Building 54: GT=0, Pred=3, Offset=3
# Building 55: GT=0, Pred=0, Offset=0
# Building 56: GT=0, Pred=1, Offset=1
# Building 57: GT=0, Pred=0, Offset=0
# Building 58: GT=0, Pred=2, Offset=2
# Building 59: GT=0, Pred=0, Offset=0
# Building 60: GT=0, Pred=2, Offset=2
# Building 61: GT=0, Pred=0, Offset=0
# Building 62: GT=0, Pred=0, Offset=0
# Building 64: GT=0, Pred=0, Offset=0
# Building 66: GT=0, Pred=3, Offset=3
# Building 67: GT=0, Pred=0, Offset=0
# Building 68: GT=0, Pred=3, Offset=3
# Building 69: GT=0, Pred=0, Offset=0
# Building 70: GT=0, Pred=0, Offset=0
# Building 71: GT=0, Pred=2, Offset=2
# Building 72: GT=0, Pred=2, Offset=2
# Building 74: GT=0, Pred=0, Offset=0
# Building 76: GT=0, Pred=0, Offset=0
# Building 77: GT=0, Pred=2, Offset=2
# Building 78: GT=0, Pred=2, Offset=2
# Building 79: GT=0, Pred=0, Offset=0
# Building 80: GT=0, Pred=0, Offset=0
# Building 81: GT=0, Pred=1, Offset=1
# Building 82: GT=0, Pred=0, Offset=0
# Building 83: GT=0, Pred=0, Offset=0
# Building 84: GT=0, Pred=0, Offset=0
# Building 85: GT=0, Pred=3, Offset=3
# Building 86: GT=0, Pred=0, Offset=0
# Building 87: GT=0, Pred=0, Offset=0
# Building 89: GT=0, Pred=0, Offset=0
# Building 90: GT=0, Pred=0, Offset=0
# Building 91: GT=0, Pred=0, Offset=0
# Building 92: GT=0, Pred=0, Offset=0
# Building 94: GT=0, Pred=0, Offset=0
# Building 95: GT=0, Pred=2, Offset=2
# Building 96: GT=0, Pred=0, Offset=0
# Building 97: GT=0, Pred=0, Offset=0
# Building 98: GT=0, Pred=3, Offset=3
# Building 99: GT=0, Pred=0, Offset=0
# Building 100: GT=0, Pred=0, Offset=0
# Building 101: GT=0, Pred=0, Offset=0
# Building 102: GT=0, Pred=0, Offset=0
# Building 103: GT=0, Pred=0, Offset=0
# Building 104: GT=0, Pred=2, Offset=2
# Building 105: GT=0, Pred=2, Offset=2
# Building 106: GT=0, Pred=0, Offset=0
# Building 107: GT=0, Pred=3, Offset=3
# Building 108: GT=0, Pred=2, Offset=2
# Building 109: GT=0, Pred=3, Offset=3
# Building 110: GT=0, Pred=0, Offset=0
# Building 111: GT=0, Pred=2, Offset=2
# Building 112: GT=0, Pred=2, Offset=2
# Building 113: GT=0, Pred=0, Offset=0
# Building 114: GT=0, Pred=3, Offset=3
# Building 117: GT=0, Pred=0, Offset=0
# Building 118: GT=0, Pred=0, Offset=0
# Building 120: GT=0, Pred=1, Offset=1
# Building 121: GT=0, Pred=0, Offset=0
# Building 122: GT=0, Pred=2, Offset=2
# Building 123: GT=0, Pred=0, Offset=0
# Building 124: GT=0, Pred=0, Offset=0
# Building 126: GT=0, Pred=0, Offset=0
# Building 127: GT=0, Pred=0, Offset=0
# Building 128: GT=0, Pred=0, Offset=0
# Building 129: GT=0, Pred=2, Offset=2
# Building 130: GT=0, Pred=0, Offset=0
# Building 131: GT=0, Pred=0, Offset=0
# Building 133: GT=0, Pred=0, Offset=0
# Building 134: GT=0, Pred=2, Offset=2
# Building 135: GT=0, Pred=0, Offset=0
# Building 136: GT=0, Pred=3, Offset=3
# Building 137: GT=0, Pred=0, Offset=0
# Building 138: GT=0, Pred=0, Offset=0
# Building 139: GT=0, Pred=0, Offset=0
# Building 140: GT=0, Pred=0, Offset=0
# Building 141: GT=0, Pred=0, Offset=0
# Building 142: GT=0, Pred=0, Offset=0
# Building 143: GT=0, Pred=0, Offset=0
# Building 144: GT=0, Pred=2, Offset=2
# Building 145: GT=0, Pred=0, Offset=0
# Building 146: GT=0, Pred=3, Offset=3
# Building 147: GT=0, Pred=0, Offset=0
# Building 148: GT=0, Pred=0, Offset=0
# Building 149: GT=0, Pred=0, Offset=0
# Building 150: GT=0, Pred=2, Offset=2
# Building 153: GT=0, Pred=0, Offset=0
# Building 154: GT=0, Pred=0, Offset=0
# Building 155: GT=0, Pred=0, Offset=0
# Building 156: GT=0, Pred=2, Offset=2
# Building 157: GT=0, Pred=0, Offset=0
# Building 158: GT=0, Pred=0, Offset=0
# Building 159: GT=0, Pred=0, Offset=0
# Building 160: GT=0, Pred=1, Offset=1
# Building 161: GT=0, Pred=2, Offset=2
# Building 162: GT=0, Pred=0, Offset=0
# Building 163: GT=0, Pred=3, Offset=3
# Building 164: GT=0, Pred=2, Offset=2
# Building 165: GT=0, Pred=0, Offset=0
# Building 166: GT=0, Pred=0, Offset=0
# Building 168: GT=0, Pred=0, Offset=0
# Building 169: GT=0, Pred=2, Offset=2
# Building 171: GT=0, Pred=0, Offset=0
# Building 172: GT=0, Pred=0, Offset=0
# Building 173: GT=0, Pred=1, Offset=1
# Building 174: GT=0, Pred=3, Offset=3
# Building 175: GT=0, Pred=0, Offset=0
# Building 176: GT=0, Pred=0, Offset=0
# Building 177: GT=0, Pred=3, Offset=3
# Building 178: GT=0, Pred=3, Offset=3
# Building 182: GT=0, Pred=0, Offset=0
# Building 183: GT=0, Pred=0, Offset=0
# Building 184: GT=0, Pred=0, Offset=0
# Building 185: GT=0, Pred=0, Offset=0
# Building 187: GT=0, Pred=0, Offset=0
# Building 188: GT=0, Pred=1, Offset=1
# Building 189: GT=0, Pred=2, Offset=2
# Building 190: GT=0, Pred=0, Offset=0
# Building 191: GT=0, Pred=0, Offset=0
# Building 192: GT=0, Pred=0, Offset=0
# Building 193: GT=0, Pred=0, Offset=0
# Building 194: GT=0, Pred=1, Offset=1
# Building 195: GT=0, Pred=1, Offset=1
# Building 196: GT=0, Pred=0, Offset=0
# Building 197: GT=0, Pred=0, Offset=0
# Building 198: GT=0, Pred=2, Offset=2
# Building 199: GT=0, Pred=0, Offset=0
# Building 200: GT=0, Pred=1, Offset=1
# Building 201: GT=0, Pred=0, Offset=0
# Building 203: GT=0, Pred=0, Offset=0
# Building 204: GT=0, Pred=0, Offset=0
# Building 205: GT=0, Pred=2, Offset=2
# Building 206: GT=0, Pred=0, Offset=0
# Building 207: GT=0, Pred=0, Offset=0
# Building 208: GT=0, Pred=0, Offset=0
# Building 209: GT=0, Pred=2, Offset=2
# Building 211: GT=0, Pred=0, Offset=0
# Building 212: GT=0, Pred=0, Offset=0
# Building 213: GT=0, Pred=3, Offset=3
# Building 214: GT=0, Pred=2, Offset=2
# Building 215: GT=0, Pred=1, Offset=1
# Building 216: GT=0, Pred=2, Offset=2
# Building 217: GT=0, Pred=3, Offset=3
# Building 218: GT=0, Pred=0, Offset=0
# Building 219: GT=0, Pred=0, Offset=0
# Building 220: GT=0, Pred=0, Offset=0
# Building 221: GT=0, Pred=0, Offset=0
# Building 222: GT=0, Pred=0, Offset=0
# Building 223: GT=0, Pred=0, Offset=0
# Building 224: GT=0, Pred=0, Offset=0
# Building 225: GT=0, Pred=0, Offset=0
# Building 227: GT=0, Pred=0, Offset=0
# Building 228: GT=0, Pred=0, Offset=0
# Building 229: GT=0, Pred=0, Offset=0
# Building 230: GT=0, Pred=1, Offset=1
# Building 231: GT=0, Pred=0, Offset=0
# Building 232: GT=0, Pred=1, Offset=1
# Building 233: GT=0, Pred=0, Offset=0
# Building 235: GT=0, Pred=0, Offset=0
# Building 236: GT=0, Pred=0, Offset=0
# Building 237: GT=0, Pred=0, Offset=0
# Building 238: GT=0, Pred=2, Offset=2
# Building 239: GT=0, Pred=1, Offset=1
# Building 240: GT=0, Pred=0, Offset=0
# Building 241: GT=0, Pred=0, Offset=0
# Building 242: GT=0, Pred=0, Offset=0
# Building 243: GT=0, Pred=0, Offset=0
# Building 244: GT=0, Pred=0, Offset=0
# Building 245: GT=0, Pred=2, Offset=2
# Building 246: GT=0, Pred=0, Offset=0
# Building 247: GT=0, Pred=0, Offset=0
# Building 248: GT=0, Pred=0, Offset=0
# Building 249: GT=0, Pred=1, Offset=1
# Building 250: GT=0, Pred=0, Offset=0
# Building 251: GT=0, Pred=2, Offset=2
# Building 252: GT=0, Pred=0, Offset=0
# Building 253: GT=0, Pred=3, Offset=3
# Building 254: GT=0, Pred=0, Offset=0
# Building 255: GT=0, Pred=0, Offset=0
# Building 256: GT=0, Pred=0, Offset=0
# Building 257: GT=0, Pred=3, Offset=3
# Building 259: GT=0, Pred=0, Offset=0
# Building 261: GT=0, Pred=0, Offset=0
# Building 262: GT=0, Pred=2, Offset=2
# Building 263: GT=0, Pred=0, Offset=0
# Building 264: GT=0, Pred=0, Offset=0
# Building 266: GT=0, Pred=2, Offset=2
# Building 267: GT=0, Pred=0, Offset=0
# Building 269: GT=0, Pred=0, Offset=0
# Building 271: GT=0, Pred=0, Offset=0
# Building 272: GT=0, Pred=0, Offset=0
# Building 273: GT=0, Pred=0, Offset=0
# Building 274: GT=0, Pred=0, Offset=0
# Building 275: GT=0, Pred=0, Offset=0
# Building 276: GT=0, Pred=0, Offset=0
# Building 277: GT=0, Pred=0, Offset=0
# Building 278: GT=0, Pred=0, Offset=0
# Building 279: GT=0, Pred=3, Offset=3
# Building 280: GT=0, Pred=0, Offset=0
# Building 281: GT=0, Pred=3, Offset=3
# Building 282: GT=0, Pred=2, Offset=2
# Building 283: GT=0, Pred=0, Offset=0
# Building 284: GT=0, Pred=0, Offset=0
# Building 285: GT=0, Pred=0, Offset=0
# Building 286: GT=0, Pred=2, Offset=2
# Building 287: GT=0, Pred=2, Offset=2
# Building 288: GT=0, Pred=0, Offset=0
# Building 289: GT=0, Pred=0, Offset=0
# Building 290: GT=0, Pred=0, Offset=0
# Building 291: GT=0, Pred=0, Offset=0
# Building 292: GT=0, Pred=0, Offset=0
# Building 293: GT=0, Pred=0, Offset=0
# Building 294: GT=0, Pred=3, Offset=3
# Building 295: GT=0, Pred=1, Offset=1
# Building 298: GT=0, Pred=0, Offset=0
# Building 299: GT=0, Pred=0, Offset=0
# Building 300: GT=0, Pred=0, Offset=0
# Building 301: GT=0, Pred=2, Offset=2
# Building 302: GT=0, Pred=0, Offset=0
# Building 303: GT=0, Pred=0, Offset=0
# Building 304: GT=0, Pred=0, Offset=0
# Building 305: GT=0, Pred=0, Offset=0
# Building 306: GT=0, Pred=0, Offset=0
# Building 307: GT=0, Pred=0, Offset=0
# Building 308: GT=0, Pred=0, Offset=0
# Building 309: GT=0, Pred=0, Offset=0
# Building 310: GT=0, Pred=1, Offset=1
# Building 311: GT=0, Pred=0, Offset=0
# Building 312: GT=0, Pred=3, Offset=3
# Building 313: GT=0, Pred=0, Offset=0
# Building 314: GT=0, Pred=0, Offset=0
# Building 315: GT=0, Pred=3, Offset=3
# Building 316: GT=0, Pred=0, Offset=0
# Building 317: GT=0, Pred=0, Offset=0
# Building 318: GT=0, Pred=0, Offset=0
# Building 320: GT=0, Pred=0, Offset=0
# Building 321: GT=0, Pred=0, Offset=0
# Building 322: GT=0, Pred=0, Offset=0
# Building 323: GT=0, Pred=3, Offset=3
# Building 325: GT=0, Pred=0, Offset=0
# Building 326: GT=0, Pred=2, Offset=2
# Building 328: GT=0, Pred=2, Offset=2
# Building 329: GT=0, Pred=0, Offset=0
# Building 331: GT=0, Pred=0, Offset=0
# Building 332: GT=0, Pred=0, Offset=0
# Building 334: GT=0, Pred=0, Offset=0
# Building 335: GT=0, Pred=0, Offset=0
# Building 336: GT=0, Pred=0, Offset=0
# Building 337: GT=0, Pred=0, Offset=0
# Building 338: GT=0, Pred=0, Offset=0
# Building 339: GT=0, Pred=0, Offset=0
# Building 340: GT=0, Pred=0, Offset=0
# Building 341: GT=0, Pred=2, Offset=2
# Building 342: GT=0, Pred=1, Offset=1
# Building 343: GT=0, Pred=0, Offset=0
# Building 345: GT=0, Pred=2, Offset=2
# Building 346: GT=0, Pred=0, Offset=0
# Building 350: GT=0, Pred=1, Offset=1
# Building 351: GT=0, Pred=0, Offset=0
# Building 352: GT=0, Pred=0, Offset=0
# Building 353: GT=0, Pred=3, Offset=3
# Building 355: GT=0, Pred=0, Offset=0
# Building 356: GT=0, Pred=0, Offset=0
# Building 357: GT=0, Pred=0, Offset=0
# Building 358: GT=0, Pred=0, Offset=0
# Building 359: GT=0, Pred=2, Offset=2
# Building 360: GT=0, Pred=0, Offset=0
# Building 361: GT=0, Pred=0, Offset=0
# Building 362: GT=0, Pred=1, Offset=1
# Building 363: GT=0, Pred=0, Offset=0
# Building 364: GT=0, Pred=0, Offset=0
# Building 365: GT=0, Pred=0, Offset=0
# Building 366: GT=0, Pred=0, Offset=0
# Building 367: GT=0, Pred=2, Offset=2
# Building 368: GT=0, Pred=2, Offset=2
# Building 369: GT=0, Pred=3, Offset=3
# Building 370: GT=0, Pred=3, Offset=3
# Building 371: GT=0, Pred=0, Offset=0
# Building 372: GT=0, Pred=0, Offset=0
# Building 373: GT=0, Pred=0, Offset=0
# Building 374: GT=0, Pred=0, Offset=0
# Building 375: GT=0, Pred=3, Offset=3
# Building 376: GT=0, Pred=2, Offset=2
# Building 377: GT=0, Pred=0, Offset=0
# Building 378: GT=0, Pred=0, Offset=0
# Building 379: GT=0, Pred=0, Offset=0
# Building 381: GT=0, Pred=0, Offset=0
# Building 382: GT=0, Pred=0, Offset=0
# Building 383: GT=0, Pred=0, Offset=0
# Building 384: GT=0, Pred=0, Offset=0
# Building 385: GT=0, Pred=0, Offset=0
# Building 386: GT=0, Pred=0, Offset=0
# Building 388: GT=0, Pred=0, Offset=0
# Building 389: GT=0, Pred=0, Offset=0
# Building 390: GT=0, Pred=0, Offset=0
# Building 391: GT=0, Pred=0, Offset=0
# Building 392: GT=0, Pred=0, Offset=0
# Building 393: GT=0, Pred=0, Offset=0
# Building 395: GT=0, Pred=0, Offset=0
# Building 397: GT=0, Pred=0, Offset=0
# Building 398: GT=0, Pred=0, Offset=0
# Building 399: GT=0, Pred=0, Offset=0
# Building 400: GT=0, Pred=0, Offset=0
# Building 401: GT=0, Pred=1, Offset=1
# Building 402: GT=0, Pred=0, Offset=0
# Building 403: GT=0, Pred=0, Offset=0
# Building 404: GT=0, Pred=0, Offset=0
# Building 405: GT=0, Pred=0, Offset=0
# Building 406: GT=0, Pred=0, Offset=0
# Building 407: GT=0, Pred=0, Offset=0
# Building 408: GT=0, Pred=0, Offset=0
# Building 409: GT=0, Pred=3, Offset=3
# Building 410: GT=0, Pred=0, Offset=0
# Building 411: GT=0, Pred=0, Offset=0
# Building 412: GT=0, Pred=0, Offset=0
# Building 413: GT=0, Pred=0, Offset=0
# Building 414: GT=0, Pred=1, Offset=1
# Building 415: GT=0, Pred=1, Offset=1
# Building 416: GT=0, Pred=3, Offset=3
# Building 418: GT=0, Pred=0, Offset=0
# Building 420: GT=0, Pred=0, Offset=0
# Building 421: GT=0, Pred=0, Offset=0
# Building 422: GT=0, Pred=0, Offset=0
# Building 423: GT=0, Pred=2, Offset=2
# Building 424: GT=0, Pred=2, Offset=2
# Building 425: GT=0, Pred=0, Offset=0
# Building 426: GT=0, Pred=0, Offset=0
# Building 427: GT=0, Pred=3, Offset=3
# Building 428: GT=0, Pred=0, Offset=0
# Building 429: GT=0, Pred=3, Offset=3
# Building 430: GT=0, Pred=0, Offset=0
# Building 431: GT=0, Pred=1, Offset=1
# Building 432: GT=0, Pred=2, Offset=2
# Building 433: GT=0, Pred=1, Offset=1
# Building 434: GT=0, Pred=0, Offset=0
# Building 435: GT=0, Pred=0, Offset=0
# Building 436: GT=0, Pred=0, Offset=0
# Building 437: GT=0, Pred=0, Offset=0
# Building 438: GT=0, Pred=0, Offset=0
# Building 439: GT=0, Pred=2, Offset=2
# Building 440: GT=0, Pred=0, Offset=0
# Building 441: GT=0, Pred=0, Offset=0
# Building 442: GT=0, Pred=0, Offset=0
# Building 443: GT=0, Pred=1, Offset=1
# Building 444: GT=0, Pred=3, Offset=3
# Building 445: GT=0, Pred=0, Offset=0
# Building 446: GT=0, Pred=0, Offset=0
# Building 447: GT=0, Pred=0, Offset=0
# Building 448: GT=0, Pred=0, Offset=0
# Building 449: GT=0, Pred=0, Offset=0
# Building 450: GT=0, Pred=0, Offset=0
# Building 451: GT=0, Pred=0, Offset=0
# Building 452: GT=0, Pred=0, Offset=0
# Building 453: GT=0, Pred=0, Offset=0
# Building 454: GT=0, Pred=3, Offset=3
# Building 457: GT=0, Pred=0, Offset=0
# Building 458: GT=0, Pred=3, Offset=3
# Building 459: GT=0, Pred=0, Offset=0
# Building 460: GT=0, Pred=1, Offset=1
# Building 461: GT=0, Pred=0, Offset=0
# Building 462: GT=0, Pred=0, Offset=0
# Building 463: GT=0, Pred=3, Offset=3
# Building 464: GT=0, Pred=0, Offset=0
# Building 465: GT=0, Pred=2, Offset=2
# Building 466: GT=0, Pred=0, Offset=0
# Building 467: GT=0, Pred=0, Offset=0
# Building 468: GT=0, Pred=0, Offset=0
# Building 469: GT=0, Pred=0, Offset=0
# Building 470: GT=0, Pred=2, Offset=2
# Building 471: GT=0, Pred=1, Offset=1
# Building 473: GT=0, Pred=0, Offset=0
# Building 474: GT=0, Pred=0, Offset=0
# Building 475: GT=0, Pred=0, Offset=0
# Building 476: GT=0, Pred=3, Offset=3
# Building 477: GT=0, Pred=0, Offset=0
# Building 478: GT=0, Pred=0, Offset=0
# Building 480: GT=0, Pred=0, Offset=0
# Building 481: GT=0, Pred=0, Offset=0
# Building 482: GT=0, Pred=1, Offset=1
# Building 483: GT=0, Pred=0, Offset=0
# Building 484: GT=0, Pred=0, Offset=0
# Building 485: GT=0, Pred=0, Offset=0
# Building 486: GT=0, Pred=3, Offset=3
# Building 487: GT=0, Pred=2, Offset=2
# Building 488: GT=0, Pred=0, Offset=0
# Building 489: GT=0, Pred=0, Offset=0
# Building 490: GT=0, Pred=0, Offset=0
# Building 492: GT=0, Pred=0, Offset=0
# Building 494: GT=0, Pred=0, Offset=0
# Building 495: GT=0, Pred=0, Offset=0
# Building 496: GT=0, Pred=0, Offset=0
# Building 499: GT=0, Pred=3, Offset=3
# Building 500: GT=0, Pred=0, Offset=0
# Building 501: GT=0, Pred=2, Offset=2
# Building 502: GT=0, Pred=2, Offset=2
# Building 503: GT=0, Pred=0, Offset=0
# Building 504: GT=0, Pred=0, Offset=0
# Building 505: GT=0, Pred=0, Offset=0
# Building 506: GT=0, Pred=2, Offset=2
# Building 507: GT=0, Pred=0, Offset=0
# Building 508: GT=0, Pred=0, Offset=0
# Building 509: GT=0, Pred=0, Offset=0
# Building 510: GT=0, Pred=0, Offset=0
# Building 511: GT=0, Pred=0, Offset=0
# Building 512: GT=0, Pred=0, Offset=0
# Building 513: GT=0, Pred=3, Offset=3
# Building 514: GT=0, Pred=0, Offset=0
# Building 515: GT=0, Pred=0, Offset=0
# Building 516: GT=0, Pred=2, Offset=2
# Building 517: GT=0, Pred=1, Offset=1
# Building 520: GT=0, Pred=0, Offset=0
# Building 521: GT=0, Pred=2, Offset=2
# Building 522: GT=0, Pred=2, Offset=2
# Building 523: GT=0, Pred=0, Offset=0
# Building 524: GT=0, Pred=2, Offset=2
# Building 525: GT=0, Pred=0, Offset=0
# Building 526: GT=0, Pred=3, Offset=3
# Building 527: GT=0, Pred=0, Offset=0
# Building 528: GT=0, Pred=0, Offset=0
# Building 529: GT=0, Pred=0, Offset=0
# Building 530: GT=0, Pred=0, Offset=0
# Building 531: GT=0, Pred=3, Offset=3
# Building 533: GT=0, Pred=1, Offset=1
# Building 535: GT=0, Pred=0, Offset=0
# Building 536: GT=0, Pred=2, Offset=2
# Building 537: GT=0, Pred=0, Offset=0
# Building 538: GT=0, Pred=0, Offset=0
# Building 540: GT=0, Pred=3, Offset=3
# Building 541: GT=0, Pred=0, Offset=0
# Building 544: GT=0, Pred=2, Offset=2
# Building 545: GT=0, Pred=0, Offset=0
# Building 546: GT=0, Pred=3, Offset=3
# Building 547: GT=0, Pred=0, Offset=0
# Building 548: GT=0, Pred=0, Offset=0
# Building 549: GT=0, Pred=0, Offset=0
# Building 550: GT=0, Pred=0, Offset=0
# Building 551: GT=0, Pred=0, Offset=0
# Building 552: GT=0, Pred=2, Offset=2
# Building 553: GT=0, Pred=0, Offset=0
# Building 554: GT=0, Pred=1, Offset=1
# Building 555: GT=0, Pred=0, Offset=0
# Building 556: GT=0, Pred=2, Offset=2
# Building 558: GT=0, Pred=0, Offset=0
# Building 559: GT=0, Pred=0, Offset=0
# Building 560: GT=0, Pred=3, Offset=3
# Building 561: GT=0, Pred=0, Offset=0
# Building 562: GT=0, Pred=1, Offset=1
# Building 563: GT=0, Pred=0, Offset=0
# Building 564: GT=0, Pred=2, Offset=2
# Building 565: GT=0, Pred=0, Offset=0
# Building 566: GT=0, Pred=2, Offset=2
# Building 567: GT=0, Pred=0, Offset=0
# Building 568: GT=0, Pred=0, Offset=0
# Building 569: GT=0, Pred=0, Offset=0
# Building 570: GT=0, Pred=0, Offset=0
# Building 571: GT=0, Pred=0, Offset=0
# Building 572: GT=0, Pred=0, Offset=0
# Building 573: GT=0, Pred=2, Offset=2
# Building 574: GT=0, Pred=3, Offset=3
# Building 575: GT=0, Pred=0, Offset=0
# Building 577: GT=0, Pred=3, Offset=3
# Building 578: GT=0, Pred=3, Offset=3
# Building 579: GT=0, Pred=0, Offset=0
# Building 580: GT=0, Pred=0, Offset=0
# Building 581: GT=0, Pred=0, Offset=0
# Building 582: GT=0, Pred=0, Offset=0
# Building 583: GT=0, Pred=0, Offset=0
# Building 584: GT=0, Pred=1, Offset=1
# Building 585: GT=0, Pred=0, Offset=0
# Building 586: GT=0, Pred=2, Offset=2
# Building 587: GT=0, Pred=0, Offset=0
# Building 588: GT=0, Pred=0, Offset=0
# Building 589: GT=0, Pred=0, Offset=0
# Building 590: GT=0, Pred=0, Offset=0
# Building 591: GT=0, Pred=0, Offset=0
# Building 592: GT=0, Pred=0, Offset=0
# Building 593: GT=0, Pred=3, Offset=3
# Building 594: GT=0, Pred=0, Offset=0
# Building 595: GT=0, Pred=0, Offset=0
# Building 596: GT=0, Pred=0, Offset=0
# Building 597: GT=0, Pred=0, Offset=0
# Building 598: GT=0, Pred=0, Offset=0
# Building 599: GT=0, Pred=0, Offset=0
# Building 600: GT=0, Pred=0, Offset=0
# Building 601: GT=0, Pred=0, Offset=0
# Building 602: GT=0, Pred=0, Offset=0
# Building 603: GT=0, Pred=2, Offset=2
# Building 604: GT=0, Pred=0, Offset=0
# Building 605: GT=0, Pred=0, Offset=0
# Building 606: GT=0, Pred=0, Offset=0
# Building 607: GT=0, Pred=3, Offset=3
# Building 608: GT=0, Pred=0, Offset=0
# Building 609: GT=0, Pred=0, Offset=0
# Building 610: GT=0, Pred=0, Offset=0
# Building 611: GT=0, Pred=3, Offset=3
# Building 612: GT=0, Pred=0, Offset=0
# Building 613: GT=0, Pred=2, Offset=2
# Building 614: GT=0, Pred=0, Offset=0
# Building 615: GT=0, Pred=0, Offset=0
# Building 616: GT=0, Pred=0, Offset=0
# Building 617: GT=0, Pred=0, Offset=0
# Building 619: GT=0, Pred=0, Offset=0
# Building 620: GT=0, Pred=0, Offset=0
# Building 622: GT=0, Pred=0, Offset=0
# Building 623: GT=0, Pred=0, Offset=0
# Building 624: GT=0, Pred=0, Offset=0
# Building 625: GT=0, Pred=0, Offset=0
# Building 626: GT=0, Pred=0, Offset=0
# Building 628: GT=0, Pred=0, Offset=0
# Building 629: GT=0, Pred=2, Offset=2
# Building 630: GT=0, Pred=0, Offset=0
# Building 632: GT=0, Pred=0, Offset=0
# Building 633: GT=0, Pred=0, Offset=0
# Building 634: GT=0, Pred=0, Offset=0
# Building 635: GT=0, Pred=0, Offset=0
# Building 636: GT=0, Pred=0, Offset=0
# Building 637: GT=0, Pred=1, Offset=1
# Building 638: GT=0, Pred=1, Offset=1
# Building 639: GT=0, Pred=2, Offset=2
# Building 640: GT=0, Pred=0, Offset=0
# Building 641: GT=0, Pred=0, Offset=0
# Building 642: GT=0, Pred=0, Offset=0
# Building 643: GT=0, Pred=1, Offset=1
# Building 644: GT=0, Pred=0, Offset=0
# Building 645: GT=0, Pred=2, Offset=2
# Building 646: GT=0, Pred=0, Offset=0
# Building 647: GT=0, Pred=0, Offset=0
# Building 648: GT=0, Pred=0, Offset=0
# Building 649: GT=0, Pred=1, Offset=1
# Building 650: GT=0, Pred=0, Offset=0
# Building 652: GT=0, Pred=1, Offset=1
# Building 653: GT=0, Pred=3, Offset=3
# Building 654: GT=0, Pred=0, Offset=0
# Building 655: GT=0, Pred=3, Offset=3
# Building 656: GT=0, Pred=0, Offset=0
# Building 657: GT=0, Pred=0, Offset=0
# Building 658: GT=0, Pred=0, Offset=0
# Building 660: GT=0, Pred=2, Offset=2
# Building 661: GT=0, Pred=0, Offset=0
# Building 663: GT=0, Pred=0, Offset=0
# Building 664: GT=0, Pred=0, Offset=0
# Building 665: GT=0, Pred=0, Offset=0
# Building 666: GT=0, Pred=1, Offset=1
# Building 667: GT=0, Pred=0, Offset=0
# Building 668: GT=0, Pred=0, Offset=0
# Building 669: GT=0, Pred=1, Offset=1
# Building 670: GT=0, Pred=0, Offset=0
# Building 671: GT=0, Pred=2, Offset=2
# Building 672: GT=0, Pred=0, Offset=0
# Building 674: GT=0, Pred=3, Offset=3
# Building 675: GT=0, Pred=0, Offset=0
# Building 676: GT=0, Pred=0, Offset=0
# Building 677: GT=0, Pred=0, Offset=0
# Building 678: GT=0, Pred=0, Offset=0
# Building 679: GT=0, Pred=2, Offset=2
# Building 680: GT=0, Pred=0, Offset=0
# Building 681: GT=0, Pred=3, Offset=3
# Building 682: GT=0, Pred=0, Offset=0
# Building 683: GT=0, Pred=0, Offset=0
# Building 684: GT=0, Pred=0, Offset=0
# Building 685: GT=0, Pred=2, Offset=2
# Building 686: GT=0, Pred=0, Offset=0
# Building 687: GT=0, Pred=3, Offset=3
# Building 688: GT=0, Pred=0, Offset=0
# Building 689: GT=0, Pred=0, Offset=0
# Building 690: GT=0, Pred=0, Offset=0
# Building 691: GT=0, Pred=0, Offset=0
# Building 692: GT=0, Pred=0, Offset=0
# Building 693: GT=0, Pred=0, Offset=0
# Building 694: GT=0, Pred=0, Offset=0
# Building 695: GT=0, Pred=0, Offset=0
# Building 696: GT=0, Pred=2, Offset=2
# Building 698: GT=0, Pred=0, Offset=0
# Building 699: GT=0, Pred=0, Offset=0
# Building 700: GT=0, Pred=1, Offset=1
# Building 701: GT=0, Pred=0, Offset=0
# Building 702: GT=0, Pred=0, Offset=0
# Building 703: GT=0, Pred=0, Offset=0
# Building 704: GT=0, Pred=0, Offset=0
# Building 705: GT=0, Pred=0, Offset=0
# Building 706: GT=0, Pred=0, Offset=0
# Building 707: GT=0, Pred=0, Offset=0
# Building 708: GT=0, Pred=0, Offset=0
# Building 709: GT=0, Pred=3, Offset=3
# Building 711: GT=0, Pred=0, Offset=0
# Building 712: GT=0, Pred=0, Offset=0
# Building 713: GT=0, Pred=0, Offset=0
# Building 714: GT=0, Pred=3, Offset=3
# Building 717: GT=0, Pred=0, Offset=0
# Building 718: GT=0, Pred=0, Offset=0
# Building 719: GT=0, Pred=0, Offset=0
# Building 720: GT=0, Pred=3, Offset=3
# Building 721: GT=0, Pred=0, Offset=0
# Building 722: GT=0, Pred=0, Offset=0
# Building 723: GT=0, Pred=1, Offset=1
# Building 724: GT=0, Pred=0, Offset=0
# Building 725: GT=0, Pred=0, Offset=0
#
# Sample: hurricane-florence_00000543
# Building 0: GT=0, Pred=2, Offset=2
# Building 1: GT=0, Pred=0, Offset=0
# Building 3: GT=0, Pred=2, Offset=2
# Building 4: GT=0, Pred=0, Offset=0
# Building 5: GT=0, Pred=0, Offset=0
# Building 7: GT=0, Pred=2, Offset=2
#
# Sample: hurricane-matthew_00000111
# Building 0: GT=3, Pred=2, Offset=-1
# Building 1: GT=3, Pred=0, Offset=-3
# Building 2: GT=3, Pred=0, Offset=-3
# Building 3: GT=3, Pred=2, Offset=-1
# Building 4: GT=1, Pred=2, Offset=1
# Building 5: GT=2, Pred=2, Offset=0
# Building 6: GT=3, Pred=0, Offset=-3
# Building 7: GT=3, Pred=2, Offset=-1
# Building 8: GT=1, Pred=2, Offset=1
# Building 9: GT=1, Pred=0, Offset=-1
# Building 10: GT=1, Pred=2, Offset=1
# Building 11: GT=1, Pred=2, Offset=1
# Building 12: GT=1, Pred=2, Offset=1
# Building 13: GT=2, Pred=2, Offset=0
# Building 14: GT=3, Pred=2, Offset=-1
# Building 15: GT=3, Pred=0, Offset=-3
#
# Sample: hurricane-harvey_00000294
#
# Sample: santa-rosa-wildfire_00000068
# Building 0: GT=3, Pred=2, Offset=-1
# Building 3: GT=0, Pred=2, Offset=2
# Building 5: GT=3, Pred=2, Offset=-1
# Building 6: GT=3, Pred=0, Offset=-3
# Building 8: GT=3, Pred=2, Offset=-1
# Building 9: GT=3, Pred=3, Offset=0
# Building 10: GT=1, Pred=2, Offset=1
# Building 11: GT=3, Pred=3, Offset=0
# Building 13: GT=0, Pred=2, Offset=2
# Building 14: GT=3, Pred=2, Offset=-1
# Building 15: GT=3, Pred=2, Offset=-1
# Building 16: GT=3, Pred=1, Offset=-2
# Building 17: GT=3, Pred=2, Offset=-1
# Building 18: GT=3, Pred=2, Offset=-1
# Building 19: GT=0, Pred=0, Offset=0
# Building 20: GT=3, Pred=2, Offset=-1
# Building 22: GT=0, Pred=2, Offset=2
# Building 23: GT=3, Pred=2, Offset=-1
# Building 24: GT=3, Pred=2, Offset=-1
# Building 26: GT=0, Pred=2, Offset=2
# Building 27: GT=3, Pred=3, Offset=0
# Building 28: GT=3, Pred=2, Offset=-1
# Building 29: GT=3, Pred=2, Offset=-1
# Building 30: GT=3, Pred=2, Offset=-1
# Building 32: GT=0, Pred=3, Offset=3
#
# --- Offset Summary ---
# Offset 0: 464 instances
# Offset 2: 88 instances
# Offset 3: 63 instances
# Offset 1: 51 instances
# Offset -1: 18 instances
# Offset -3: 5 instances
# Offset -2: 1 instances

# %% [markdown]
# socal-fire_00000325
